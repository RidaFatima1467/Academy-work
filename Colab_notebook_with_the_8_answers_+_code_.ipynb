# %% [markdown]
# <a href="https://colab.research.google.com/github/RidaFatima1467/Academy-work/blob/main/Colab_notebook_with_the_8_answers_%2B_code_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **difference loc and iloc?**
#
# **loc[]:**
# loc is used to find the certain data from rows and columns labels.
#
#
# **iloc[]:**
# is used to access certain data through integer positions.

# %% [markdown]
# **how do you check for and count missing values in DataFrame**
#
# isnull().sum()

# %% [markdown]
# **Filter rows where both conditions are true?**
#
# AND(&) operation is used to filter rows because both conditions are true.

# %% [markdown]
# **Difference b\w count df.copy() & just assigning df2 = df?**
#
# df.copy():
# df.copy is used make a exact copy of dataset.
#
# df2 = df:
# in it the dataset which is stored in df is assigned to df2.

# %%
import pandas as pd
df= pd.read_csv("/content/tested-selected-columns.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare
# 0   330911   7.8292
# 1   363272   7.0000
# 2   240276   9.6875
# 3   315154   8.6625
# 4  3101298  12.2875

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare
# 413   NaN      0      0           A.5. 3236    8.0500
# 414  39.0      0      0            PC 17758  108.9000
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500
# 416   NaN      0      0              359309    8.0500
# 417   NaN      1      1                2668   22.3583

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# dtype: int64

# %% [markdown]
# **1. Total passenger?**

# %%
print("Total passengers:", df.shape[0])
# Out:
# Total passengers: 418

# %% [markdown]
# **2. Passenger Survived in Titanic?**

# %%
survived= df[df["Survived"]==1]
print(len(survived))
# Out:
# 152

# %% [markdown]
# **3. how much passenger not survived?**

# %%
survived= df[df["Survived"]==0]
print(len(survived))
# Out:
# 266

# %% [markdown]
# **4. How much female passengers present?**

# %%
Female_passengers = df[df["Sex"]=="female"]
print(len(Female_passengers))
# Out:
# 152

# %% [markdown]
# **5. How much female passengers present?**

# %%
male_passengers = df[df["Sex"]=="male"]
print(len(male_passengers))
# Out:
# 266

# %% [markdown]
# **6. how much young passengers present?**

# %%
Young_passengers = df[df["Age"]<=30]
print(len(Young_passengers))
# Out:
# 200

# %% [markdown]
# **7. Total fare collected?**

# %%
total_fare = df["Fare"].sum()
print(total_fare)
# Out:
# 14856.5376
